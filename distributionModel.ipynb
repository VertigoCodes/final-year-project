# %%
#LIBRARIES IMPORT
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing

# %%
noOfShops = 136
area = 361

sourceData = np.random.chisquare(4,noOfShops)

sourceDataMean = np.mean(sourceData)
sourceDataStd = np.std(sourceData)

# %%
iterations = 100
num_values = 136
results = np.zeros((iterations, num_values))

for i in range(iterations):
    results[i, :] = np.random.chisquare(df=2, size=num_values)

average_results = np.mean(results, axis=0)
average_results
# Out:
# array([2.22101531, 2.01724851, 1.90936358, 2.12942174, 2.16933345,
#        1.8150327 , 2.02371775, 2.27924033, 2.0397153 , 2.04306364,
#        2.34614744, 1.93561218, 2.15346871, 1.91542659, 1.9165291 ,
#        2.31992559, 2.26989346, 2.06060741, 2.1399399 , 1.76149622,
#        1.67746928, 1.93372239, 2.06872702, 2.20840463, 2.06724326,
#        1.89740242, 1.79776077, 1.94605962, 1.88321002, 2.13514951,
#        1.98889075, 1.98296143, 1.72184981, 1.83300588, 2.3904689 ,
#        1.66692363, 1.93797295, 1.90643391, 1.83130125, 1.82133348,
#        1.96165423, 1.91874671, 2.00168777, 1.78362256, 1.93728719,
#        2.17313063, 2.13531783, 2.2145174 , 1.73232888, 2.18296591,
#        2.16706132, 1.84549036, 1.47796117, 2.28050942, 1.96128379,
#        1.7160329 , 1.99686585, 1.96557211, 1.74260937, 2.13263869,
#        2.46998396, 1.83420132, 1.8835463 , 2.18432567, 2.13570231,
#        1.91804867, 1.89152563, 1.86968471, 1.97137677, 1.9893328 ,
#        2.50762749, 2.31000092, 2.07126906, 1.8709383 , 2.01232336,
#        2.00487725, 2.10122489, 2.2593329 , 1.86562033, 2.02042005,
#        1.81937764, 1.98373934, 1.87471427, 2.22093806, 1.9257865 ,
#        1.91398838, 1.78963677, 1.98109083, 2.14264696, 2.41955267,
#        1.92630017, 2.26487929, 1.78234104, 2.20290581, 1.91028411,
#        2.01478625, 2.0945326 , 2.16524154, 1.72987284, 2.08336297,
#        1.76546532, 2.09866873, 2.17577666, 2.11270161, 2.19306881,
#        1.90374134, 2.01718176, 2.11324112, 1.90937098, 2.20942493,
#        1.83542506, 1.96977161, 1.96987663, 2.14129737, 2.21905447,
#        1.73285958, 1.66475208, 1.84898155, 1.80778114, 2.37539942,
#        2.20524799, 1.9931453 , 1.96707808, 1.92308706, 2.21900979,
#        1.96824774, 2.07392275, 2.0942162 , 1.6550917 , 1.93730696,
#        1.85196929, 2.16825685, 1.92775931, 2.03611784, 1.94895827,
#        1.88868119])

# %%
average_results_mean = np.mean(average_results)
average_results_std = np.std(average_results)

# %%
sns.displot(sourceData, kde=True, legend=True)
#sns.scatterplot(sourceData, legend=True, palette='viridis')

plt.axvline(sourceDataMean, color='red', label='Mean')
plt.axvline(sourceDataMean + sourceDataStd, color='green', label='Standard deviation')
plt.axvline(sourceDataMean - sourceDataStd, color='green')

# add labels and title to the plot
plt.xlabel("Value")
plt.ylabel("Density")
plt.title("Distances of Shops from Goddown - Srirangam")

print("Mean of distances = {} \nStandard Deviation of distances = {}".format(sourceDataMean, sourceDataStd))
# Out:
# Mean of distances = 3.9810388492762003
# Standard Deviation of distances = 3.0558176620424318

# %%
print("Min : {}\nMax : {}".format(sourceData.min(), sourceData.max()))
# Out:
# Min : 0.1120692115613682
# Max : 14.907807687160409

# %%
sns.displot(average_results, kde=True, legend=True)
#sns.scatterplot(sourceData, legend=True, palette='viridis')

plt.axvline(average_results_mean, color='red', label='Mean')
plt.axvline(average_results_mean + average_results_std, color='green', label='Standard deviation')
plt.axvline(average_results_mean - average_results_std, color='green')

# add labels and title to the plot
plt.xlabel("Value")
plt.ylabel("Density")
plt.title("Distances of Shops from Goddown - Srirangam")

print("Mean of distances = {} \nStandard Deviation of distances = {}".format(average_results_mean, average_results_std))
# Out:
# Mean of distances = 2.0060959641958105
# Standard Deviation of distances = 0.18429994907612524
